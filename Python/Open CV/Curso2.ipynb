# %%
# Imagenes con Nunpy (arrays) en Python

# %%
import numpy as np  # Manejo de arreglos y operaciones numéricas
import matplotlib.pyplot as plt  # Generación de gráficos y visualización de datos
from PIL import Image  # Manipulación y procesamiento de imágenes

# %%
pwd
# Out:
# 'C:\\Users\\valen\\OneDrive\\Documentos\\OpenCV'

# %%
cd C:\Users\valen\OneDrive\Documentos\OpenCV
# Out:
# C:\Users\valen\OneDrive\Documentos\OpenCV

# %%
imagen = Image.open("perrito.jpg")

# %%
imagen
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x412>

# %%
type(imagen)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
imagen.size
# Out:
# (800, 412)

# %%
array_imagen = np.asarray(imagen) #Convertir imagen en array

# %%
array_imagen
# Out:
# array([[[ 46,  31,   2],
#         [ 48,  33,   4],
#         [ 52,  35,   5],
#         ...,
#         [  1,   1,   1],
#         [  1,   1,   1],
#         [  1,   1,   1]],
#
#        [[ 46,  31,   2],
#         [ 48,  33,   2],
#         [ 52,  35,   5],
#         ...,
#         [  1,   1,   1],
#         [  1,   1,   1],
#         [  1,   1,   1]],
#
#        [[ 47,  32,   1],
#         [ 49,  34,   3],
#         [ 53,  36,   6],
#         ...,
#         [  1,   1,   1],
#         [  1,   1,   1],
#         [  1,   1,   1]],
#
#        ...,
#
#        [[ 68, 122,  28],
#         [ 76, 128,  46],
#         [ 87, 138,  71],
#         ...,
#         [ 67,  82,  13],
#         [ 80,  97,  26],
#         [ 88, 110,  38]],
#
#        [[ 62, 114,  16],
#         [ 71, 123,  38],
#         [ 79, 131,  59],
#         ...,
#         [ 99, 111,  47],
#         [101, 116,  49],
#         [ 89, 109,  40]],
#
#        [[ 54, 105,   4],
#         [ 66, 116,  27],
#         [ 69, 121,  46],
# ...

# %%
plt.imshow(array_imagen) #Mostrar imagen en array

# %%
array_imagen.shape
# Out:
# (412, 800, 3)

# %%
array_imagen[:,:,0] #Todas las filas y todas las colunmas en la dimension del color ROJO
# Out:
# array([[ 46,  48,  52, ...,   1,   1,   1],
#        [ 46,  48,  52, ...,   1,   1,   1],
#        [ 47,  49,  53, ...,   1,   1,   1],
#        ...,
#        [ 68,  76,  87, ...,  67,  80,  88],
#        [ 62,  71,  79, ...,  99, 101,  89],
#        [ 54,  66,  69, ..., 136, 126,  86]], dtype=uint8)

# %%
array_imagen[:,:,1]
# Out:
# array([[ 31,  33,  35, ...,   1,   1,   1],
#        [ 31,  33,  35, ...,   1,   1,   1],
#        [ 32,  34,  36, ...,   1,   1,   1],
#        ...,
#        [122, 128, 138, ...,  82,  97, 110],
#        [114, 123, 131, ..., 111, 116, 109],
#        [105, 116, 121, ..., 144, 138, 105]], dtype=uint8)
