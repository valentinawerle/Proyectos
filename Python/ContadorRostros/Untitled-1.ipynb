# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
imagen = cv2.imread('/home/adrianwerle/Descargas/perro.jpg')

# %%
type(imagen)
# Out:
# numpy.ndarray

# %%
imagen.shape
# Out:
# (1280, 1920, 3)

# %%
plt.imshow(imagen)

# %%
imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagen)

# %%
imagen_blanco_negro = cv2.imread('/home/adrianwerle/Descargas/perro.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(imagen_blanco_negro, cmap='gray')
